# %% [markdown]
# # Analise Exploratoria — Distancias REGIC
# Notebook para analise da base de distancias intermunicipais.

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/distancias_regic.csv', dtype={'origem_codigo_ibge': str, 'destino_codigo_ibge': str})
df.head()

# %%
df.describe()

# %%
fig = px.histogram(df, x='distancia_km', nbins=50, title='Distribuicao das Distancias Intermunicipais')
fig.show()
